# %%
import csv
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.svm import LinearSVC

def expected(codeID):
    code = ""
    if codeID == 0:
        code = "Stairs"
    elif codeID == 1:
        code = "Drive"
    elif codeID == 2:
        code = "Walk"
    elif codeID == 3:
        code = "Run"
    elif codeID == 4:
        code = "Sitting"
    return code

# %%
stairxTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
stairyTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
stairzTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]

stairxTestGroups = [[], [], [], [], [], []]
stairyTestGroups = [[], [], [], [], [], []]
stairzTestGroups = [[], [], [], [], [], []]

with open('real stairs.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    currentGroupx = []
    currentGroupy = []
    currentGroupz = []
    i = 1
    for row in csv_reader:
        if float(row["time"]) < i*10:
            currentGroupx.append(float(row["ax"]))
            currentGroupy.append(float(row["ay"]))
            currentGroupz.append(float(row["az"]))
        else:
            if i <= 24:
                stairxTrainGroups[i-1] = currentGroupx
                stairyTrainGroups[i-1] = currentGroupy
                stairzTrainGroups[i-1] = currentGroupz
            else:
                stairxTestGroups[i-25] = currentGroupx
                stairyTestGroups[i-25] = currentGroupy
                stairzTestGroups[i-25] = currentGroupz
            i += 1
            currentGroupx = []
            currentGroupy = []
            currentGroupz = []

# %%
drivexTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
driveyTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
drivezTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]

drivexTestGroups = [[], [], [], [], [], []]
driveyTestGroups = [[], [], [], [], [], []]
drivezTestGroups = [[], [], [], [], [], []]

with open('drive.csv', mode='r') as csv_file2:
    csv_reader2 = csv.DictReader(csv_file2)
    currentGroupx = []
    currentGroupy = []
    currentGroupz = []
    i = 1
    for row in csv_reader2:
        if float(row["time"]) < i*10:
            currentGroupx.append(float(row["ax"]))
            currentGroupy.append(float(row["ay"]))
            currentGroupz.append(float(row["az"]))
        else:
            if i <= 24:
                drivexTrainGroups[i-1] = currentGroupx
                driveyTrainGroups[i-1] = currentGroupy
                drivezTrainGroups[i-1] = currentGroupz
            else:
                drivexTestGroups[i-25] = currentGroupx
                driveyTestGroups[i-25] = currentGroupy
                drivezTestGroups[i-25] = currentGroupz
            i += 1
            currentGroupx = []
            currentGroupy = []
            currentGroupz = []

# %%
walkxTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
walkyTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
walkzTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]

walkxTestGroups = [[], [], [], [], [], []]
walkyTestGroups = [[], [], [], [], [], []]
walkzTestGroups = [[], [], [], [], [], []]

with open('walker.csv', mode='r') as csv_file3:
    csv_reader3 = csv.DictReader(csv_file3)
    currentGroupx = []
    currentGroupy = []
    currentGroupz = []
    i = 1
    for row in csv_reader3:
        if float(row["time"]) < i*10:
            currentGroupx.append(float(row["ax"]))
            currentGroupy.append(float(row["ay"]))
            currentGroupz.append(float(row["az"]))
        else:
            if i <= 24:
                walkxTrainGroups[i-1] = currentGroupx
                walkyTrainGroups[i-1] = currentGroupy
                walkzTrainGroups[i-1] = currentGroupz
            else:
                walkxTestGroups[i-25] = currentGroupx
                walkyTestGroups[i-25] = currentGroupy
                walkzTestGroups[i-25] = currentGroupz
            i += 1
            currentGroupx = []
            currentGroupy = []
            currentGroupz = []

# %%
runxTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
runyTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
runzTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]

runxTestGroups = [[], [], [], [], [], []]
runyTestGroups = [[], [], [], [], [], []]
runzTestGroups = [[], [], [], [], [], []]

with open('run.csv', mode='r') as csv_file4:
    csv_reader4 = csv.DictReader(csv_file4)
    currentGroupx = []
    currentGroupy = []
    currentGroupz = []
    i = 1
    for row in csv_reader4:
        if float(row["time"]) < i*10:
            currentGroupx.append(float(row["ax"]))
            currentGroupy.append(float(row["ay"]))
            currentGroupz.append(float(row["az"]))
        else:
            if i <= 24:
                runxTrainGroups[i-1] = currentGroupx
                runyTrainGroups[i-1] = currentGroupy
                runzTrainGroups[i-1] = currentGroupz
            else:
                runxTestGroups[i-25] = currentGroupx
                runyTestGroups[i-25] = currentGroupy
                runzTestGroups[i-25] = currentGroupz
            i += 1
            currentGroupx = []
            currentGroupy = []
            currentGroupz = []

# %%
sittingxTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
sittingyTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]
sittingzTrainGroups = [[], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], [],
          [], [], [], [], [], [], [], []]

sittingxTestGroups = [[], [], [], [], [], []]
sittingyTestGroups = [[], [], [], [], [], []]
sittingzTestGroups = [[], [], [], [], [], []]

with open('pocketSit.csv', mode='r') as csv_file5:
    csv_reader5 = csv.DictReader(csv_file5)
    currentGroupx = []
    currentGroupy = []
    currentGroupz = []
    i = 1
    for row in csv_reader5:
        if float(row["time"]) < i*10:
            currentGroupx.append(float(row["ax"]))
            currentGroupy.append(float(row["ay"]))
            currentGroupz.append(float(row["az"]))
        else:
            if i <= 24:
                sittingxTrainGroups[i-1] = currentGroupx
                sittingyTrainGroups[i-1] = currentGroupy
                sittingzTrainGroups[i-1] = currentGroupz
            else:
                sittingxTestGroups[i-25] = currentGroupx
                sittingyTestGroups[i-25] = currentGroupy
                sittingzTestGroups[i-25] = currentGroupz
            i += 1
            currentGroupx = []
            currentGroupy = []
            currentGroupz = []

# %%
k = 0
trainAves = []
trainTarget = []
for k in range(len(stairxTrainGroups)):
    m = 0
    stairxTotal, stairyTotal, stairzTotal = 0, 0, 0
    drivexTotal, driveyTotal, drivezTotal = 0, 0, 0
    walkxTotal, walkyTotal, walkzTotal = 0, 0, 0
    runxTotal, runyTotal, runzTotal = 0, 0, 0
    sittingxTotal, sittingyTotal, sittingzTotal = 0, 0, 0

    for m in range(len(stairxTrainGroups[k])):
        stairxTotal += stairxTrainGroups[k][m]
        stairyTotal += stairyTrainGroups[k][m]
        stairzTotal += stairzTrainGroups[k][m]
    m = 0
    for m in range(len(drivexTrainGroups[k])):
        drivexTotal += drivexTrainGroups[k][m]
        driveyTotal += driveyTrainGroups[k][m]
        drivezTotal += drivezTrainGroups[k][m]
    m = 0
    for m in range(len(walkxTrainGroups[k])):
        walkxTotal += walkxTrainGroups[k][m]
        walkyTotal += walkyTrainGroups[k][m]
        walkzTotal += walkzTrainGroups[k][m]
    m = 0
    for m in range(len(runxTrainGroups[k])):
        runxTotal += runxTrainGroups[k][m]
        runyTotal += runyTrainGroups[k][m]
        runzTotal += runzTrainGroups[k][m]
    m = 0
    for m in range(len(sittingxTrainGroups[k])):
        sittingxTotal += sittingxTrainGroups[k][m]
        sittingyTotal += sittingyTrainGroups[k][m]
        sittingzTotal += sittingzTrainGroups[k][m]
        
    trainAves.append([stairxTotal/len(stairxTrainGroups[k]), stairyTotal/len(stairyTrainGroups[k]), 
                     stairzTotal/len(stairzTrainGroups[k]), np.std(stairxTrainGroups[k]), np.std(stairyTrainGroups[k]),
                     np.std(stairzTrainGroups[k])])
    trainTarget.append(0)
    trainAves.append([drivexTotal/len(drivexTrainGroups[k]), driveyTotal/len(driveyTrainGroups[k]), 
                     drivezTotal/len(drivezTrainGroups[k]), np.std(drivexTrainGroups[k]), np.std(driveyTrainGroups[k]),
                     np.std(drivezTrainGroups[k])])
    trainTarget.append(1)
    trainAves.append([walkxTotal/len(walkxTrainGroups[k]), walkyTotal/len(walkyTrainGroups[k]), 
                     walkzTotal/len(walkzTrainGroups[k]), np.std(walkxTrainGroups[k]), np.std(walkyTrainGroups[k]),
                     np.std(walkzTrainGroups[k])])
    trainTarget.append(2)
    trainAves.append([runxTotal/len(runxTrainGroups[k]), runyTotal/len(runyTrainGroups[k]), 
                     runzTotal/len(runzTrainGroups[k]), np.std(runxTrainGroups[k]), np.std(runyTrainGroups[k]),
                     np.std(runzTrainGroups[k])])
    trainTarget.append(3)
    trainAves.append([sittingxTotal/len(sittingxTrainGroups[k]), sittingyTotal/len(sittingyTrainGroups[k]), 
                     sittingzTotal/len(sittingzTrainGroups[k]), np.std(sittingxTrainGroups[k]), 
                     np.std(sittingyTrainGroups[k]), np.std(sittingzTrainGroups[k])])
    trainTarget.append(4)

print(trainAves[0])
# Out:
# [0.516141778697001, -0.619203567735265, -0.5025148397104432, 4.539291219071878, 4.2426188956133455, 4.604324923308773]

# %%
testAves = []
testTarget = []
p = 0
for p in range(len(stairxTestGroups)):
    m = 0
    stairxTotal, stairyTotal, stairzTotal = 0, 0, 0
    drivexTotal, driveyTotal, drivezTotal = 0, 0, 0
    walkxTotal, walkyTotal, walkzTotal = 0, 0, 0
    runxTotal, runyTotal, runzTotal = 0, 0, 0
    sittingxTotal, sittingyTotal, sittingzTotal = 0, 0, 0

    for m in range(len(stairxTestGroups[p])):
        stairxTotal += stairxTestGroups[p][m]
        stairyTotal += stairyTestGroups[p][m]
        stairzTotal += stairzTestGroups[p][m]
    m = 0
    
    for m in range(len(drivexTestGroups[p])):
        drivexTotal += drivexTestGroups[p][m]
        driveyTotal += driveyTestGroups[p][m]
        drivezTotal += drivezTrainGroups[p][m]
    m = 0
    
    for m in range(len(walkxTestGroups[p])):
        walkxTotal += walkxTestGroups[p][m]
        walkyTotal += walkyTestGroups[p][m]
        walkzTotal += walkzTestGroups[p][m]
    m = 0
    
    for m in range(len(runxTestGroups[p])):
        runxTotal += runxTestGroups[p][m]
        runyTotal += runyTestGroups[p][m]
        runzTotal += runzTestGroups[p][m]
    m = 0
    
    for m in range(len(sittingxTestGroups[p])):
        sittingxTotal += sittingxTestGroups[p][m]
        sittingyTotal += sittingyTestGroups[p][m]
        sittingzTotal += sittingzTestGroups[p][m]
    
    testAves.append([stairxTotal/len(stairxTestGroups[p]), stairyTotal/len(stairyTestGroups[p]), 
                 stairzTotal/len(stairzTestGroups[p]), np.std(stairxTestGroups[p]), np.std(stairyTestGroups[p]),
                     np.std(stairzTestGroups[p])])
    testTarget.append(0)
    testAves.append([drivexTotal/len(drivexTestGroups[p]), driveyTotal/len(driveyTestGroups[p]), 
                 drivezTotal/len(drivezTestGroups[p]), np.std(drivexTestGroups[p]), np.std(driveyTestGroups[p]),
                     np.std(drivezTestGroups[p])])
    testTarget.append(1)
    testAves.append([walkxTotal/len(walkxTestGroups[p]), walkyTotal/len(walkyTestGroups[p]), 
                 walkzTotal/len(walkzTestGroups[p]), np.std(walkxTestGroups[p]), np.std(walkyTestGroups[p]),
                     np.std(walkzTestGroups[p])])
    testTarget.append(2)
    testAves.append([runxTotal/len(runxTestGroups[p]), runyTotal/len(runyTestGroups[p]), 
                 runzTotal/len(runzTestGroups[p]), np.std(runxTestGroups[p]), np.std(runyTestGroups[p]),
                     np.std(runzTestGroups[p])])
    testTarget.append(3)
    testAves.append([sittingxTotal/len(sittingxTestGroups[p]), sittingyTotal/len(sittingyTestGroups[p]), 
                 sittingzTotal/len(sittingzTestGroups[p]), np.std(sittingxTestGroups[p]), np.std(sittingyTestGroups[p]),
                     np.std(sittingzTestGroups[p])])
    testTarget.append(4)
print(testAves[0])
# Out:
# [0.07809418666666636, -0.5233436266666676, -0.1332837866666668, 4.538062281084392, 3.787714038793766, 2.5842271342823424]

# %%
logReg = LogisticRegression()
logReg.fit(trainAves, trainTarget)
predictionLog = logReg.predict(testAves)
i = 0
correctReg = 0
for i in range(len(testTarget)):
    if testTarget[i] != predictionLog[i]:
        print("Entry", i, "Expected:", expected(testTarget[i]), "Got:", expected(predictionLog[i]))
    else:
        correctReg += 1
        
print("Score:", correctReg, "out of:", len(testTarget))
# Out:
# Entry 16 Expected: Drive Got: Sitting
# Score: 29 out of: 30
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
decTree = DecisionTreeClassifier()
decTree.fit(trainAves, trainTarget)
predictionTree = decTree.predict(testAves)
i = 0
correctTree = 0
for i in range(len(testTarget)):
    if testTarget[i] != predictionTree[i]:
        print("Entry", i, "Expected:", expected(testTarget[i]), "Got:", expected(predictionTree[i]))
    else:
        correctTree += 1
        
print("Score:", correctTree, "out of:", len(testTarget))
plot_tree(decTree)
# Out:
# Score: 30 out of: 30
# [Text(213.05454545454546, 203.85, 'X[5] <= 7.346\ngini = 0.8\nsamples = 120\nvalue = [24, 24, 24, 24, 24]'),
#  Text(182.61818181818182, 176.67000000000002, 'X[4] <= 3.156\ngini = 0.75\nsamples = 96\nvalue = [24, 24, 24, 0, 24]'),
#  Text(121.74545454545455, 149.49, 'X[3] <= 0.055\ngini = 0.5\nsamples = 48\nvalue = [0, 24, 0, 0, 24]'),
#  Text(91.30909090909091, 122.31, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 0, 20]'),
#  Text(152.1818181818182, 122.31, 'X[5] <= 2.516\ngini = 0.245\nsamples = 28\nvalue = [0, 24, 0, 0, 4]'),
#  Text(121.74545454545455, 95.13, 'X[5] <= 0.043\ngini = 0.198\nsamples = 27\nvalue = [0, 24, 0, 0, 3]'),
#  Text(60.872727272727275, 67.94999999999999, 'X[2] <= 0.001\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 0, 0, 2]'),
#  Text(30.436363636363637, 40.77000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(91.30909090909091, 40.77000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
# ...

# %%
decSVC = LinearSVC()
decSVC.fit(trainAves, trainTarget)
predictionSCV = decSVC.predict(testAves)
i = 0
correctSVC = 0
for i in range(len(testTarget)):
    if testTarget[i] != predictionSCV[i]:
        print("Entry", i, "Expected:", expected(testTarget[i]), "Got:", expected(predictionSCV[i]))
    else:
        correctSVC += 1
        
print("Score:", correctSVC, "out of:", len(testTarget))
# Out:
# Entry 16 Expected: Drive Got: Sitting
# Score: 29 out of: 30
# C:\Users\User\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
kNeigh = KNeighborsClassifier(n_neighbors=1)
kNeigh.fit(trainAves, trainTarget)
predictionNeigh = kNeigh.predict(testAves)
i = 0
correctNeigh = 0
for i in range(len(testTarget)):
    if testTarget[i] != predictionNeigh[i]:
        print("Entry", i, "Expected:", expected(testTarget[i]), "Got:", expected(predictionNeigh[i]))
    else:
        correctNeigh += 1
        
print("Score:", correctNeigh, "out of:", len(testTarget))
# Out:
# Score: 30 out of: 30
